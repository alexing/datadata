# %%
import re
from collections import Counter
import pandas as pd
import numpy as np

# %%
drexler_df = pd.read_csv('data/drexler_complete_lyrics.csv', sep=';')
drexler_df['words'] = drexler_df.lyrics.str.strip().str.split('[\W_]+')
drexler_df['words']
# Out:
# 0      [El, perfume, de, la, sal, Del, cabo, Santa, M...
# 1      [Nos, delata, el, equipaje, Y, la, duda, al, c...
# 2      [Se, va, la, tarde, en, Zanja, Honda, La, play...
# 3      [Mabel, dejó, El, bolso, con, unas, amigas, Y,...
# 4      [Luna, del, Cabo, Boca, de, túnel, Lunar, plat...
# 5      [Ella, se, pinta, con, un, sylvapen, Dibujándo...
# 6      [Como, un, tatuaje, desteñido, Me, iré, borran...
# 7      [Mírenla, salir, sobre, la, marea, Nadie, que,...
# 8      [Tu, caricia, no, me, afecta, Yo, la, puedo, t...
# 9      [En, una, quinta, De, la, calle, Caiguá, En, u...
# 10     [Una, bolsa, de, leche, encallada, en, la, are...
# 11     [Poco, fue, lo, que, quedó, De, su, boca, carm...
# 12     [Erase, una, noche, común, era, en, una, mesa,...
# 13     [Fuente, de, luz, de, bengala, ventana, hacia,...
# 14     [Salgo, a, la, rambla, de, Malvin, A, respirar...
# 15     [No, cruzaré, Tu, lado, de, la, cama, Quiero, ...
# 16     [Tengo, un, pañuelo, negro, entre, las, manos,...
# 17     [Cuando, la, noche, pasea, Más, allá, de, mi, ...
# 18     [Tomé, de, un, trago, el, veneno, De, esos, oj...
# 19     [El, perfume, de, la, sal, Del, cabo, Santa, M...
# 20     [Se, va, la, tarde, en, Zanja, Honda, La, play...
# 21     [Mabel, dejó, El, bolso, con, unas, amigas, Y,...
# 22     [Tu, caricia, no, me, afecta, Yo, la, puedo, t...
# 23     [No, hay, rincón, en, esta, casa, Que, no, te,...
# 24     [Ana, Qué, no, daría, yo, por, ver, un, día, T...
# 25     [Nuestra, primera, intención, era, hacerlo, en...
# 26     [Ven, cura, esta, pena, Quítame, estas, ganas,...
# 27     [Cuatro, estrellas, blancas, sobre, fondo, neg...
# 28     [Onda, de, mar, En, que, flota, este, blues, T...
# 29     [Hazme, un, lugar, en, tu, almohada, Junto, a,...
#                              ...
# 102    [Te, vi, llegar, Y, así, sin, mas, Desatar, mi...
# 103    [Claro, que, lo, sé, Lo, tengo, más, que, clar...
# 104    [En, tu, propia, fuente, llorará, la, luna, Co...
# 105    [Estoy, aquí, de, paso, Yo, soy, un, pasajero,...
# 106    [Varias, primaveras, atrás, El, viento, cambió...
# 107    [Entrar, en, este, verso, como, el, viento, Qu...
# 108    [La, idea, es, eternamente, nueva, Cae, la, no...
# 109    [Europa, 1939, Todos, decían, que, no, en, las...
# 110    [Todo, cambia, de, bolsillo, Sin, el, mínimo, ...
# 111    [Volviste, como, si, nada, Como, si, el, tiemp...
# 112    [Voy, con, una, trayectoria, lenta, Por, mucho...
# 113    [Yo, miraba, la, luna, de, Rasquí, Tumbado, en...
# 114    [Vine, hasta, el, mar, con, la, noche, en, la,...
# 115    [Que, el, pulso, no, me, tiemble, en, el, ulti...
# 116    [Proyecto, de, vendaval, Protagonista, central...
# 117    [Todo, Cae, Tarde, o, temprano, A, pesar, de, ...
# 118    [Mi, anhelo, no, está, Mi, anhelo, se, fue, de...
# 119    [Quién, le, roba, un, beso, a, Maracaná, Urugu...
# 120    [Tu, historia, es, tan, antigua, como, las, re...
# 121    [Ponemos, nota, sobre, nota, Palabra, sobre, p...
# 122    [Dame, una, noche, de, asilo, en, tu, regazo, ...
# 123    [Una, gota, rueda, sobre, el, hielo, y, cuelga...
# 124    [El, tiempo, era, entonces, dinamita, Vivíamos...
# 125    [Desde, lo, profundo, de, los, cromosomas, De,...
# 126    [Apenas, nos, pusimos, en, dos, pies, Comenzam...
# 127    [Fuimos, cerrando, uno, a, uno, cuatro, bares,...
# 128    [Te, salgo, a, buscar, quimera, Mariposa, de, ...
# 129    [Duró, tu, amor, lo, que, un, salvavidas, de, ...
# 130    [Todo, el, mundo, intentando, venderte, algo, ...
# 131    [Que, viva, la, telefonía, En, todas, sus, var...
# Name: words, Length: 132, dtype: object

# %% [markdown]
# Create a list of all the lyrics tokenized

# %%
corpora = []
for a_sentence in drexler_df['words']:
    new_lower_sentence = []
    for a_word in a_sentence:
        new_lower_sentence.append(a_word.lower())
    corpora.extend(new_lower_sentence)

# %%
from nltk.corpus import stopwords
spanish_stopwords = stopwords.words('spanish') + ['na']

# %% [markdown]
# Countword them

# %%
nonPunct = re.compile('.*[A-Za-z0-9].*')  # must contain a letter or digit
filtered = [w for w in corpora if nonPunct.match(w) and w not in spanish_stopwords]
counts_drexler = Counter(filtered)
counts_drexler
# Out:
# Counter({'perfume': 14,
#          'sal': 7,
#          'cabo': 4,
#          'santa': 6,
#          'maría': 2,
#          'recobrándome': 2,
#          'piel': 34,
#          'dándome': 3,
#          'bienvenida': 3,
#          'voy': 29,
#          'saliendo': 2,
#          'caminar': 4,
#          'gestos': 3,
#          'demorados': 2,
#          'quiero': 45,
#          'oírla': 2,
#          'respirar': 8,
#          'durmiéndome': 2,
#          'regazo': 4,
#          'viento': 34,
#          'viene': 9,
#          'abraza': 2,
#          'acuerda': 2,
#          'buscándome': 3,
#          'cosquillas': 2,
#          'besos': 10,
#          'nunca': 23,
#          'di': 2,
#          'repite': 3,
#          '2': 3,
#          'veces': 11,
#          'delata': 1,
#          'equipaje': 3,
#          'duda': 8,
#          'prudencia': 2,
#          'pueblerina': 1,
#          'silencio': 14,
#          'catalán': 1,
#          'niebla': 2,
#          'barcelona': 1,
#          'cómo': 21,
#          'púdico': 1,
#          'tapiz': 1,
#          'allá': 14,
#          'vamos': 12,
#          'soñolientos': 1,
#          'tras': 5,
#          'sombra': 10,
#          'gaüdí': 1,
#          'importan': 1,
#          'versiones': 1,
#          'resabios': 1,
#          'lugar': 13,
#          'postales': 1,
#          'consabidas': 1,
#          'edad': 11,
#          'catedral': 2,
#          'caricia': 5,
#          'minuciosa': 2,
#          'siglos': 3,
#          'humedad': 1,
#          'gárgolas': 1,
#          'miran': 3,
#          'sobrevuelan': 1,
#          'ciudad': 3,
#          'mojones': 1,
#          'camino': 27,
#          'ambigua': 1,
#          'cicatriz': 1,
#          'van': 14,
#          'marcando': 1,
#          'fuselaje': 1,
#          'descascarando': 1,
#          'barniz': 1,
#          'distancia': 6,
#          'oasis': 1,
#          'forma': 2,
#          'mentir': 1,
#          'visitamos': 1,
#          'museos': 1,
#          'codiciando': 1,
#          'souvenirs': 1,
#          'va': 50,
#          'tarde': 15,
#          'zanja': 2,
#          'honda': 3,
#          'playa': 8,
#          'bruma': 5,
#          'resplandor': 4,
#          'mar': 108,
#          'invoca': 2,
#          'voz': 13,
#          'dicen': 6,
#          'vuelve': 24,
#          'cada': 50,
#          'marzo': 2,
#          'canta': 4,
#          'luz': 41,
#          'faro': 5,
#          'vieron': 2,
#          'flotar': 2,
#          'hacia': 20,
#          'sur': 18,
#          'vine': 7,
#          'verte': 21,
#          'aparecida': 6,
#          'mirador': 6,
#          'música': 21,
#          'mareas': 7,
#          'ocaso': 2,
#          'detenido': 5,
#          'menos': 19,
#          'rumor': 4,
#          'da': 18,
#          'paso': 19,
#          'sonido': 8,
#          'cambio': 6,
#          'color': 9,
#          'tiré': 2,
#          'solo': 41,
#          'dunas': 4,
#          'primera': 5,
#          'oscuridad': 13,
#          'verla': 3,
#          'andar': 5,
#          'espuma': 3,
#          'toda': 13,
#          'mentira': 3,
#          'verdad': 5,
#          'dame': 19,
#          'canción': 37,
#          'crucé': 4,
#          'noche': 67,
#          'caminando': 10,
#          'cabito': 2,
#          'farol': 2,
#          'colgándome': 2,
#          'botella': 2,
#          'tentando': 2,
#          'imaginación': 2,
#          'caña': 2,
#          'vigilia': 2,
#          'vi': 17,
#          'pasar': 18,
#          'vez': 31,
#          'seguía': 2,
#          'orilla': 3,
#          'empezaba': 2,
#          'amanecer': 2,
#          'mabel': 6,
#          'dejó': 4,
#          'bolso': 3,
#          'unas': 6,
#          'amigas': 3,
#          'salió': 3,
#          'bailar': 53,
#          'luces': 4,
#          'violetas': 3,
#          'protegían': 3,
#          'mintió': 3,
#          'cruzando': 18,
#          'pista': 12,
#          'vacía': 5,
#          'abrazó': 3,
#          'sonaban': 3,
#          'lentas': 3,
#          'permitían': 3,
#          'siguió': 4,
#          'llenó': 6,
#          'giraba': 6,
#          'conversando': 3,
#          'visto': 12,
#          'alguna': 5,
#          'baile': 5,
#          'club': 3,
#          'salinas': 3,
#          'comentarios': 3,
#          'rigor': 3,
#          'mano': 24,
#          'espalda': 5,
#          'sostenía': 3,
#          'mostrador': 3,
#          'mesas': 3,
#          'salón': 4,
#          'clase': 3,
#          'multitud': 3,
#          'luna': 63,
#          'espejos': 5,
#          'aire': 20,
#          'ayudó': 3,
#          'vió': 3,
#          'oscurecer': 3,
#          'cuerpo': 17,
#          'recostándose': 3,
#          'dudó': 3,
#          'movió': 4,
#          'mejilla': 4,
#          'besó': 3,
#          'fingiendo': 3,
#          'saber': 12,
#          'mientras': 15,
#          'aprendía': 3,
#          'cambió': 7,
#          'despertándose': 3,
#          'aquel': 28,
#          'nuevo': 5,
#          'boca': 13,
#          'túnel': 1,
#          'lunar': 4,
#          'plateado': 1,
#          'nubes': 6,
#          'venimos': 2,
#          'lejos': 20,
#          'brillar': 8,
#          'blanca': 15,
#          'creciente': 1,
#          'sacerdotisa': 1,
#          'palideciente': 1,
#          'valizas': 1,
#          'nadie': 13,
#          'quiere': 15,
#          'perder': 1,
#          'queda': 12,
#          'borracho': 1,
#          'salir': 6,
#          'roja': 3,
#          'redonda': 1,
#          'cocumela': 1,
#          'fosforescente': 1,
#          'arena': 24,
#          'perdidos': 2,
#          'ríen': 2,
#          'mojan': 3,
#          'ropa': 7,
#          'pinta': 1,
#          'sylvapen': 1,
#          'dibujándose': 2,
#          'postiza': 1,
#          'rojo': 2,
#          'clavel': 1,
#          'enchastrándose': 1,
#          'preguntando': 2,
#          'si': 50,
#          'bien': 31,
#          'así': 22,
#          'femenina': 1,
#          'ignorándome': 2,
#          'macarena': 6,
#          'ser': 24,
#          'mujer': 3,
#          'mira': 8,
#          'delantal': 1,
#          'contorneándose': 2,
#          'frente': 4,
#          'espejo': 7,
#          'sabe': 10,
#          'esperar': 5,
#          'aprendiéndose': 1,
#          'aprendiendo': 2,
#          'código': 1,
#          'sutil': 4,
#          'milenario': 1,
#          'sorprendiéndome': 1,
#          'sorprendiéndola': 1,
#          'cintura': 4,
#          'mirada': 10,
#          'sueña': 2,
#          'cadencia': 1,
#          'vendrá': 1,
#          'tatuaje': 1,
#          'desteñido': 1,
#          'iré': 3,
#          'borrando': 1,
#          'irá': 3,
#          'última': 2,
#          'decolorando': 1,
#          'mes': 2,
#          'dirás': 3,
#          'medianoche': 1,
#          'segundo': 7,
#          'descuido': 2,
#          'recobrarás': 1,
#          'corazón': 57,
#          'dolor': 7,
#          'abandonado': 1,
#          'rincón': 14,
#          'pasión': 1,
#          'utilería': 1,
#          'sirve': 2,
#          'recordar': 5,
#          'madrugada': 2,
#          'ventana': 7,
#          'desvelo': 1,
#          'comprenderás': 1,
#          'mírenla': 2,
#          'marea': 2,
#          've': 5,
#          'cree': 1,
#          'veras': 2,
#          'colgar': 1,
#          'bahía': 2,
#          'vio': 5,
#          'entendería': 1,
#          'robar': 2,
#          'estela': 5,
#          'dejando': 9,
#          'afecta': 3,
#          'puedo': 28,
#          'tolerar': 3,
#          'mover': 3,
#          'pestaña': 3,
#          'parar': 8,
#          'controlar': 3,
#          'cosa': 5,
#          'digo': 9,
#          'ningún': 6,
#          'gesto': 6,
#          'pase': 9,
#          'aquí': 44,
#          'dentro': 11,
#          'vas': 13,
#          'enterar': 3,
#          'desgrana': 3,
#          'moralejas': 3,
#          'analiza': 3,
#          'porvenir': 3,
#          'jurando': 3,
#          'repetir': 3,
#          'rindo': 3,
#          'tan': 30,
#          'fácil': 4,
#          'supo': 3,
#          'doler': 3,
#          'cuentes': 3,
#          'premio': 4,
#          'caer': 13,
#          'vaivén': 4,
#          'ves': 8,
#          'revés': 3,
#          'recobrar': 3,
#          'aquella': 16,
#          'emoción': 5,
#          'desdibujó': 3,
#          'quinta': 1,
#          'calle': 5,
#          'caiguá': 2,
#          'vuelto': 3,
#          'ir': 15,
#          'sólo': 30,
#          'fuente': 7,
#          'dejaba': 1,
#          'oir': 2,
#          'reflejo': 3,
#          'cara': 4,
#          'bajo': 12,
#          'cielo': 34,
#          'azul': 13,
#          'entreví': 1,
#          'iría': 1,
#          'bolsa': 2,
#          'leche': 2,
#          'encallada': 2,
#          'murmullo': 3,
#          'cascabel': 2,
#          'salado': 3,
#          'mete': 2,
#          'venas': 2,
#          'algarabía': 3,
#          'estira': 4,
#          'sol': 15,
#          'caía': 3,
#          'velo': 2,
#          'blanco': 29,
#          'mediodía': 2,
#          'cerca': 24,
#          'presa': 4,
#          'yodo': 2,
#          'bisagra': 2,
#          'herrumbrar': 2,
#          'mundo': 24,
#          'dice': 6,
#          'probar': 2,
#          'casa': 13,
#          'hundiendo': 2,
#          'sola': 3,
#          'carnaval': 4,
#          'pasaron': 3,
#          'raya': 2,
#          'año': 4,
#          'rememorar': 4,
#          'llevaba': 2,
#          'guitarra': 12,
#          'crece': 5,
#          'horizonte': 4,
#          'carpa': 2,
#          'vuela': 11,
#          'temporal': 2,
#          'bañistas': 2,
#          'pueden': 3,
#          'esconden': 2,
#          'cargan': 2,
#          'pudieron': 2,
#          'salvar': 2,
#          'agua': 19,
#          'sangre': 4,
#          'verde': 8,
#          'desbocada': 2,
#          'rastafari': 2,
#          'barrio': 8,
#          'pocitos': 2,
#          'flota': 5,
#          'sopor': 2,
#          'grappamiel': 2,
#          'prueba': 3,
#          'madera': 5,
#          'entrepiso': 2,
#          'haciendo': 7,
#          'amor': 48,
#          'puntas': 2,
#          'pie': 9,
#          'brillo': 2,
#          'oro': 6,
#          'lente': 4,
#          'leve': 8,
#          'verano': 4,
#          'quedó': 6,
#          'carmesí': 2,
#          'foto': 3,
#          'salvador': 2,
#          'tres': 5,
#          'deseos': 1,
#          'bonfim': 1,
#          'invierno': 4,
#          'desató': 1,
#          'verso': 9,
#          'terminar': 1,
#          'cuarto': 5,
#          'hotel': 1,
#          'paraba': 1,
#          'girar': 6,
#          'tristeza': 3,
#          'portugués': 1,
#          'diez': 2,
#          'días': 6,
#          'avenida': 3,
#          'italia': 2,
#          'dedo': 1,
#          'chuy': 1,
#          'mostrando': 1,
#          'sello': 1,
#          'aduana': 1,
#          'diecinueve': 1,
#          'cumplir': 1,
#          'preguntaba': 1,
#          'dónde': 12,
#          'quedaba': 1,
#          'uruguay': 7,
#          'bailaba': 2,
#          'reía': 1,
#          'hablar': 7,
#          'acento': 1,
#          'desarmaba': 1,
#          'sonando': 2,
#          'febrero': 4,
#          'brasil': 2,
#          'entrando': 3,
#          'miraba': 11,
#          'dormir': 5,
#          'apenas': 12,
#          'acreditaba': 1,
#          'juntaba': 1,
#          'plata': 4,
#          'soñaba': 1,
#          'edén': 3,
#          'escuchaba': 1,
#          'joao': 1,
#          'gilberto': 1,
#          'pensaba': 3,
#          'volver': 6,
#          'garroneaba': 1,
#          'itapemirim': 1,
#          'velaba': 1,
#          'armario': 1,
#          'trofeos': 1,
#          'paraíso': 1,
#          'erase': 2,
#          'común': 3,
#          'mesa': 9,
#          'bar': 4,
#          'enero': 3,
#          'aquél': 3,
#          'miró': 2,
#          'manera': 12,
#          'fumar': 5,
#          'reír': 3,
#          'buscar': 5,
#          'cualquiera': 5,
#          'amar': 15,
#          'fondo': 16,
#          'gota': 9,
#          'puede': 9,
#          'tener': 6,
#          'secretos': 3,
#          'pueda': 3,
#          'contar': 2,
#          'vino': 16,
#          'después': 6,
#          'imaginar': 2,
#          'bengala': 1,
#          'barco': 6,
#          'llevandome': 1,
#          'aura': 1,
#          'clara': 4,
#          'mandala': 1,
#          'maracuyá': 1,
#          'rie': 3,
#          'gégé': 11,
#          'uh': 28,
#          'lala': 24,
#          'cruza': 4,
#          'acerca': 5,
#          'taza': 2,
#          'té': 3,
#          'apura': 1,
#          'primavera': 4,
#          'bajando': 1,
#          'ayudar': 1,
#          'suenan': 1,
#          'cuentas': 1,
#          'collar': 3,
#          'marcha': 3,
#          'escuchar': 2,
#          'mueve': 6,
#          'río': 25,
#          'bajada': 1,
#          'notas': 2,
#          'mayor': 3,
#          'salgo': 4,
#          'rambla': 2,
#          'malvin': 2,
#          'amores': 2,
#          'terraza': 1,
#          'igual': 14,
#          'sigo': 3,
#          'sonrisa': 5,
#          'aguas': 4,
#          'colores': 3,
#          'penando': 1,
#          'darme': 2,
#          'golpe': 4,
#          'pampero': 1,
#          'costado': 3,
#          'calzo': 1,
#          'auricular': 1,
#          'lennon': 1,
#          'dé': 1,
#          'norte': 3,
#          'creas': 2,
#          'consuelo': 1,
#          'vos': 14,
#          'rodeos': 2,
#          'femeninos': 1,
#          'descifro': 1,
#          'resto': 1,
#          'imagino': 1,
#          'cruzaré': 1,
#          'lado': 12,
#          'cama': 7,
#          'entender': 5,
#          'dormís': 1,
#          'reclama': 1,
#          'girando': 14,
#          'acá': 2,
#          'alcantarilla': 1,
#          'techos': 1,
#          'cordón': 1,
#          'buscando': 17,
#          'deriva': 3,
#          'radar': 2,
#          'eco': 11,
#          'pañuelo': 3,
#          'negro': 21,
#          'manos': 12,
#          'miro': 10,
#          'tocando': 8,
#          'pliegues': 2,
#          'humo': 7,
#          'embriagador': 1,
#          'pertinaz': 1,
#          'negras': 1,
#          'género': 1,
#          'dócil': 1,
#          'trapo': 2,
#          'toca': 4,
#          'escucho': 3,
#          'acariciar': 5,
#          'copiando': 3,
#          'calor': 9,
#          'hombro': 2,
#          'tiempo': 82,
#          'balcón': 7,
#          'riéndose': 4,
#          'tacto': 2,
#          'dejo': 13,
#          'sentado': 1,
#          'tela': 2,
#          'parecen': 4,
#          'pasea': 6,
#          'pretil': 4,
#          'ver': 21,
#          'afuera': 9,
#          'veas': 5,
#          'adivinar': 4,
#          'nube': 9,
#          'vapor': 7,
#          'alrededor': 12,
#          'vicio': 2,
#          'barato': 2,
#          'legal': 2,
#          'gozo': 2,
#          'anonimato': 2,
#          'interferir': 2,
#          'respiración': 2,
#          'entrar': 9,
#          'tocar': 9,
#          'querer': 4,
#          'diré': 2,
#          'voyeur': 14,
#          'aprendí': 4,
#          'horarios': 2,
#          'orden': 2,
#          'placard': 2,
#          'pude': 5,
#          'mirándote': 4,
#          'toalla': 2,
#          'sofá': 2,
#          'peinándote': 2,
#          'tranquilidad': 2,
#          'sospechar': 2,
#          'muriéndome': 3,
#          'tomé': 1,
#          'trago': 2,
#          'veneno': 1,
#          'ojos': 16,
#          'seguí': 1,
#          'canto': 8,
#          'rocas': 1,
#          'naufragué': 1,
#          'hoy': 17,
#          'fumo': 2,
#          'callado': 4,
#          'fruto': 2,
#          'codiciado': 1,
#          'conozco': 3,
#          'sabor': 2,
#          'red': 4,
#          'escondida': 1,
#          'trampa': 1,
#          'esperándome': 4,
#          'creí': 1,
#          'sincera': 2,
#          'entrega': 1,
#          'entero': 3,
#          'entregué': 1,
#          'hace': 14,
#          'siento': 10,
#          'haga': 3,
#          'regresar': 5,
#          'grano': 3,
#          'memoria': 6,
#          'arenal': 1,
#          'fuí': 2,
#          'playas': 1,
#          'día': 23,
#          'allí': 1,
#          'quedé': 2,
#          'dos': 49,
#          'años': 11,
#          'lamiendo': 1,
#          'heridas': 6,
#          'remanso': 1,
#          'acunó': 1,
#          'borraron': 1,
#          'arrugas': 1,
#          'iluminó': 1,
#          'germinaron': 1,
#          'canciónes': 1,
#          'merecía': 2,
#          'paró': 1,
#          'reloj': 2,
#          '730': 1,
#          'ana': 4,
#          'daría': 2,
#          'guarida': 1,
#          'formando': 1,
#          'banderín': 1,
#          'multicolor': 1,
#          'junto': 5,
#          'atuendo': 2,
#          'servidor': 1,
#          'cambiaría': 1,
#          'misma': 14,
#          'melodía': 1,
#          'complacerte': 1,
#          'entro': 2,
#          'cauce': 3,
#          'suelto': 4,
#          'timón': 3,
#          'abajo': 11,
#          'rumbo': 10,
#          'rendija': 2,
#          'entró': 2,
#          'quieras': 2,
#          'brillando': 3,
#          'intención': 3,
#          'hacerlo': 1,
#          'acuarela': 1,
#          'hablara': 1,
#          'colibrí': 1,
#          'policromo': 1,
#          'parado': 1,
#          'arcoiris': 1,
#          'durando': 1,
#          'director': 1,
#          'banda': 2,
#          'silbando': 1,
#          'bajito': 1,
#          'azules': 1,
#          'rojos': 1,
#          'valsecito': 2,
#          'ustedes': 1,
#          'saben': 2,
#          'señores': 1,
#          'falló': 1,
#          'presupuesto': 1,
#          'nieve': 5,
#          'carbón': 10,
#          'tecnicolor': 3,
#          'quitando': 1,
#          'primero': 3,
#          'paleta': 1,
#          'turquesa': 1,
#          'marco': 1,
#          'violeta': 2,
#          'luego': 12,
#          'carmín': 2,
#          'flores': 15,
#          'encima': 1,
#          'piano': 3,
#          'caída': 1,
#          'empieza': 7,
#          'tipos': 1,
#          'enredadera': 2,
#          'quedaban': 1,
#          'banderas': 3,
#          'viejo': 3,
#          'recuerdo': 4,
#          'final': 4,
#          'ven': 6,
#          'cura': 5,
#          'pena': 21,
#          'quítame': 1,
#          'ganas': 4,
#          'frío': 8,
#          'cruzar': 1,
#          'crujió': 1,
#          'tren': 4,
#          'señora': 1,
#          'ten': 2,
#          'piedad': 1,
#          'simple': 4,
#          'mortal': 2,
#          'herida': 4,
#          'blues': 2,
#          'incierto': 1,
#          'traerá': 1,
#          'perfumes': 1,
#          'reflejos': 1,
#          'estrella': 4,
#          'fugaz': 6,
#          'dudes': 1,
#          'hará': 3,
#          'falta': 4,
#          'uuuuu': 1,
#          'cuatro': 11,
#          'estrellas': 12,
#          'blancas': 7,
#          'cruz': 7,
#          'negra': 2,
#          'mirar': 9,
#          'nombrarte': 2,
#          'anochecer': 2,
#          'recordarte': 2,
#          'marías': 2,
#          'negros': 1,
#          'dieron': 1,
#          'recordaba': 1,
#          'ue': 6,
#          'onda': 2,
#          'toma': 4,
#          'vals': 2,
#          'supe': 9,
#          'esconder': 2,
#          'culpa': 2,
#          'bolero': 2,
#          'adueñado': 1,
#          'miras': 2,
#          'estár': 1,
#          'necesario': 1,
#          'inglés': 1,
#          'you': 12,
#          'are': 1,
#          'to': 2,
#          'blame': 1,
#          'for': 1,
#          'this': 1,
#          'that': 1,
#          'gone': 1,
#          'right': 1,
#          'my': 1,
#          'head': 1,
#          'blue': 1,
#          'hazme': 2,
#          'almohada': 3,
#          'pecho': 3,
#          'calmaré': 1,
#          'duermas': 1,
#          'cantaré': 1,
#          'cuna': 3,
#          'tacuarembó': 2,
#          'ira': 4,
#          'llevando': 4,
#          'duermo': 1,
#          'pelo': 15,
#          'perfumaré': 1,
#          'cascada': 1,
#          'jacarandá': 1,
#          'acercando': 1,
#          'escucharte': 1,
#          'olvídame': 1,
#          'zamba': 4,
#          'pide': 2,
#          'olvides': 2,
#          'deja': 9,
#          'peso': 5,
#          'sé': 26,
#          'olvido': 3,
#          'borra': 1,
#          'huella': 8,
#          'dure': 2,
#          'mas': 16,
#          'alma': 7,
#          'ninguno': 6,
#          'parte': 9,
#          'darte': 5,
#          'conocer': 3,
#          'parece': 13,
#          'ayer': 5,
#          'aclarar': 1,
#          'tampoco': 8,
#          'pasándolo': 2,
#          'mal': 2,
#          'mostró': 1,
#          'creer': 2,
#          'decir': 9,
#          'entiendo': 14,
#          'podía': 14,
#          'vivir': 14,
#          'irme': 1,
#          'debo': 2,
#          'feliz': 1,
#          'vuelves': 1,
#          'sombrío': 1,
#          'dándole': 1,
#          'vueltas': 3,
#          'desconsuelo': 1,
#          'compasión': 1,
#          'moneda': 5,
#          'lados': 4,
#          'réplica': 1,
#          'mala': 2,
#          'tómate': 1,
#          'broma': 2,
#          'salto': 3,
#          'copia': 1,
#          'original': 1,
#          'hagas': 3,
#          'caso': 5,
#          'misterio': 1,
#          'sabés': 1,
#          'peor': 6,
#          'seriedad': 1,
#          'tomársela': 1,
#          'serio': 2,
#          'hable': 2,
#          'cercanía': 1,
#          'conocés': 1,
#          'razón': 8,
#          'fé': 1,
#          'disco': 1,
#          'rayado': 1,
#          'b': 1,
#          'madre': 13,
#          'holandesa': 1,
#          'sefardí': 1,
#          'mezcla': 2,
#          'abuelos': 2,
#          'mitad': 7,
#          'padre': 7,
#          'cádiz': 1,
#          'escapó': 1,
#          'berlín': 2,
#          'vengo': 4,
#          'vienes': 1,
#          'siesta': 1,
#          'madrid': 6,
#          'suecia': 1,
#          'crió': 2,
#          'libertad': 1,
#          'casualidad': 2,
#          'claros': 1,
#          'tatarabuelo': 1,
#          'montevideo': 4,
#          'separado': 1,
#          'ocultar': 1,
#          'entenderlo': 3,
#          'buena': 4,
#          'estocolmo': 1,
#          'vinimos': 1,
#          'quiso': 3,
#          'borde': 3,
#          'falda': 1,
#          'vienen': 9,
#          'entregar': 1,
#          'fuerza': 5,
#          'barcas': 3,
#          'tenue': 1,
#          'claridad': 2,
#          'hijos': 3,
#          'lemantjá': 2,
#          'aladas': 1,
#          'espumas': 1,
#          'cantar': 4,
#          'crecen': 2,
#          'serpiente': 2,
#          'agazapada': 1,
#          'eslabón': 1,
#          'pasó': 2,
#          'cometa': 1,
#          'paredes': 1,
#          'conocía': 1,
#          'fulgor': 1,
#          'contornea': 1,
#          'aro': 1,
#          'olvidaste': 1,
#          'cabecera': 1,
#          'dudar': 1,
#          'nueva': 6,
#          'quemando': 1,
#          'miedos': 3,
#          'cenizas': 1,
#          'planetas': 1,
#          'n3om': 1,
#          'x': 1,
#          'llueve': 24,
#          'tierra': 12,
#          'atragantan': 1,
#          'alcantarillas': 1,
#          'balcones': 1,
#          'mojando': 1,
#          'tendida': 1,
#          'gente': 8,
#          'pone': 8,
#          'cubierto': 4,
#          'pasto': 4,
#          'contento': 4,
#          'mañana': 4,
#          'seguir': 8,
#          'asegura': 2,
#          'meteorología': 1,
#          'rincones': 4,
#          'país': 3,
#          'agradecida': 1,
#          'vaya': 5,
#          'tocan': 1,
#          'escucha': 1,
#          'rugir': 1,
#          'aguacero': 1,
#          'jardín': 1,
#          'alborotó': 1,
#          'hormiguero': 1,
#          'ganaba': 2,
#          'sequía': 1,
#          'humedecida': 1,
#          'milonga': 3,
#          'paraguaya': 2,
#          'prima': 3,
#          'lejana': 3,
#          'mangoré': 2,
#          'queriendo': 3,
#          ...})

# %%
counts_drexler.most_common(10)
# Out:
# [('mar', 108),
#  ('tiempo', 82),
#  ('noche', 67),
#  ('luna', 63),
#  ('corazón', 57),
#  ('bailar', 53),
#  ('va', 50),
#  ('cada', 50),
#  ('si', 50),
#  ('dos', 49)]

# %% [markdown]
# Same with related lyrics

# %%
related_df = pd.read_csv('data/related_lyrics.csv', sep=';')
related_df['words'] = related_df.lyrics.str.strip().str.split('[\W_]+')

# %%
corpora_related = []
for a_sentence in related_df['words']:
    new_lower_sentence = []
    for a_word in a_sentence:
        new_lower_sentence.append(a_word.lower())
    corpora_related.extend(new_lower_sentence)
nonPunct = re.compile('.*[A-Za-z0-9].*')  # must contain a letter or digit
filtered = [w for w in corpora_related if nonPunct.match(w) and w not in spanish_stopwords]
counts_related = Counter(filtered)
counts_related.most_common(10)
# Out:
# [('si', 2758),
#  ('amor', 2431),
#  ('referent', 1911),
#  ('quiero', 1380),
#  ('fragment', 1365),
#  ('id', 1365),
#  ('preview', 1365),
#  ('vida', 1261),
#  ('vez', 1122),
#  ('siempre', 1066)]

# %% [markdown]
# Create a strict intersection. If the word is present in Drexler corpora AND NOT in related, then keep it

# %%
words_intersected = {}
for element in counts_drexler:
    if element not in counts_related:
        words_intersected[element] = counts_drexler[element]

# %%
strict_intersection = Counter(words_intersected).most_common()

# %% [markdown]
# Threshold it. Keep actual words and not the ones which appear only once

# %%
strict_intersection[:4] #not actual words
# Out:
# [('tátara', 24), ('shh', 24), ('lalala', 12), ('gégé', 11)]

# %%
strict_intersection = strict_intersection[4:]

# %%
thresholded_intersection = []
for element in strict_intersection:
    if element[1] > 1:
        thresholded_intersection.append(element)

# %%
thresholded_intersection
# Out:
# [('rasquí', 11),
#  ('caldera', 10),
#  ('desenlace', 9),
#  ('tamborero', 8),
#  ('uruguay', 7),
#  ('aparecida', 6),
#  ('mabel', 6),
#  ('voladora', 6),
#  ('cuales', 6),
#  ('inmersión', 6),
#  ('guías', 6),
#  ('guío', 6),
#  ('electrones', 6),
#  ('judío', 5),
#  ('remo', 5),
#  ('movió', 4),
#  ('rememorar', 4),
#  ('pretil', 4),
#  ('montevideo', 4),
#  ('cubierto', 4),
#  ('juraría', 4),
#  ('abremos', 4),
#  ('rime', 4),
#  ('buela', 4),
#  ('shhhh', 4),
#  ('protegían', 3),
#  ('sonaban', 3),
#  ('permitían', 3),
#  ('salinas', 3),
#  ('comentarios', 3),
#  ('recostándose', 3),
#  ('aprendía', 3),
#  ('despertándose', 3),
#  ('pestaña', 3),
#  ('enterar', 3),
#  ('desgrana', 3),
#  ('moralejas', 3),
#  ('rindo', 3),
#  ('copiando', 3),
#  ('muriéndome', 3),
#  ('tecnicolor', 3),
#  ('barcas', 3),
#  ('computadoras', 3),
#  ('tecnología', 3),
#  ('silente', 3),
#  ('abisal', 3),
#  ('triángulo', 3),
#  ('bermudas', 3),
#  ('maracaná', 3),
#  ('silen', 3),
#  ('repetirte', 3),
#  ('recobrándome', 2),
#  ('demorados', 2),
#  ('oírla', 2),
#  ('durmiéndome', 2),
#  ('minuciosa', 2),
#  ('cabito', 2),
#  ('colgándome', 2),
#  ('ignorándome', 2),
#  ('contorneándose', 2),
#  ('mírenla', 2),
#  ('caiguá', 2),
#  ('encallada', 2),
#  ('yodo', 2),
#  ('bisagra', 2),
#  ('herrumbrar', 2),
#  ('carpa', 2),
#  ('bañistas', 2),
#  ('desbocada', 2),
#  ('rastafari', 2),
#  ('pocitos', 2),
#  ('grappamiel', 2),
#  ('entrepiso', 2),
#  ('rambla', 2),
#  ('malvin', 2),
#  ('anonimato', 2),
#  ('interferir', 2),
#  ('peinándote', 2),
#  ('sincera', 2),
#  ('atuendo', 2),
#  ('rendija', 2),
#  ('valsecito', 2),
#  ('tacuarembó', 2),
#  ('lemantjá', 2),
#  ('paraguaya', 2),
#  ('mangoré', 2),
#  ('hablándole', 2),
#  ('bodega', 2),
#  ('negrero', 2),
#  ('varsovia', 2),
#  ('sandalias', 2),
#  ('ordenadores', 2),
#  ('pedaleando', 2),
#  ('salvapantallas', 2),
#  ('darías', 2),
#  ('torino', 2),
#  ('quererlo', 2),
#  ('japonesas', 2),
#  ('árabe', 2),
#  ('chueca', 2),
#  ('malinterpreten', 2),
#  ('método', 2),
#  ('guardarme', 2),
#  ('infranqueable', 2),
#  ('guiar', 2),
#  ('caduca', 2),
#  ('noctilucas', 2),
#  ('anunciarme', 2),
#  ('llegarías', 2),
#  ('fosforecía', 2),
#  ('anticipada', 2),
#  ('encandilada', 2),
#  ('noctiluca', 2),
#  ('acurruca', 2),
#  ('ensamblados', 2),
#  ('clac', 2),
#  ('árido', 2),
#  ('ario', 2),
#  ('aclare', 2),
#  ('busquemos', 2),
#  ('orbitando', 2),
#  ('equidistantes', 2),
#  ('ahuyente', 2),
#  ('proveedor', 2),
#  ('patrono', 2),
#  ('paparazis', 2),
#  ('adecuada', 2),
#  ('teleobjetivo', 2),
#  ('concédeme', 2),
#  ('olfato', 2),
#  ('pantallas', 2),
#  ('ingenioso', 2),
#  ('entropía', 2),
#  ('oscila', 2),
#  ('reacia', 2),
#  ('opinamos', 2),
#  ('colapso', 2),
#  ('consentidas', 2),
#  ('ladronas', 2),
#  ('soltamos', 2),
#  ('honremos', 2),
#  ('cromosomas', 2),
#  ('asistentes', 2),
#  ('encajando', 2),
#  ('pertenencias', 2),
#  ('quietos', 2),
#  ('bisnietos', 2),
#  ('empaque', 2),
#  ('alatriste', 2),
#  ('catador', 2),
#  ('imprime', 2),
#  ('mantenernos', 2),
#  ('saturar', 2),
#  ('inclemente', 2),
#  ('encontraremos', 2),
#  ('pertinente', 2)]

# %%
from os import path
from wordcloud import WordCloud
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot_wordcloud_from_list(a_list):
    freqs_by_words = {}
    for a_topic_term in a_list:
        an_actual_word = a_topic_term[0]
        freqs_by_words[an_actual_word] = a_topic_term[1]
    # read the mask image
    trump_mask = np.array(Image.open("heart.jpg"))

    wc = WordCloud(background_color="white", max_words=2000, mask=trump_mask, max_font_size=100,)
    # generate word cloud
    wc.generate_from_frequencies(freqs_by_words)

    #show
    plt.figure(figsize=(20,20))
    plt.imshow(wc, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
plot_wordcloud_from_list(thresholded_intersection)

# %%
intersection = counts_drexler & counts_related

# %%
intersection.most_common()
# Out:
# [('mar', 108),
#  ('tiempo', 82),
#  ('noche', 67),
#  ('luna', 63),
#  ('corazón', 57),
#  ('bailar', 53),
#  ('va', 50),
#  ('cada', 50),
#  ('si', 50),
#  ('dos', 49),
#  ('amor', 48),
#  ('quiero', 45),
#  ('aquí', 44),
#  ('luz', 41),
#  ('solo', 41),
#  ('vida', 40),
#  ('canción', 37),
#  ('piel', 34),
#  ('viento', 34),
#  ('cielo', 34),
#  ('vez', 31),
#  ('bien', 31),
#  ('tan', 30),
#  ('sólo', 30),
#  ('voy', 29),
#  ('blanco', 29),
#  ('aquel', 28),
#  ('puedo', 28),
#  ('uh', 28),
#  ('data', 28),
#  ('camino', 27),
#  ('sé', 26),
#  ('río', 25),
#  ('vuelve', 24),
#  ('mano', 24),
#  ('arena', 24),
#  ('ser', 24),
#  ('cerca', 24),
#  ('mundo', 24),
#  ('llueve', 24),
#  ('nunca', 23),
#  ('día', 23),
#  ('así', 22),
#  ('cómo', 21),
#  ('verte', 21),
#  ('música', 21),
#  ('negro', 21),
#  ('ver', 21),
#  ('pena', 21),
#  ('aunque', 21),
#  ('hacia', 20),
#  ('aire', 20),
#  ('lejos', 20),
#  ('haces', 20),
#  ('menos', 19),
#  ('paso', 19),
#  ('dame', 19),
#  ('agua', 19),
#  ('sur', 18),
#  ('da', 18),
#  ('pasar', 18),
#  ('cruzando', 18),
#  ('horas', 18),
#  ('siempre', 18),
#  ('vi', 17),
#  ('cuerpo', 17),
#  ('buscando', 17),
#  ('hoy', 17),
#  ('aquella', 16),
#  ('fondo', 16),
#  ('vino', 16),
#  ('ojos', 16),
#  ('mas', 16),
#  ('tarde', 15),
#  ('mientras', 15),
#  ('blanca', 15),
#  ('quiere', 15),
#  ('ir', 15),
#  ('sol', 15),
#  ('amar', 15),
#  ('flores', 15),
#  ('pelo', 15),
#  ('dar', 15),
#  ('canciones', 15),
#  ('perfume', 14),
#  ('silencio', 14),
#  ('allá', 14),
#  ('van', 14),
#  ('rincón', 14),
#  ('igual', 14),
#  ('vos', 14),
#  ('girando', 14),
#  ('hace', 14),
#  ('misma', 14),
#  ('entiendo', 14),
#  ('podía', 14),
#  ('vivir', 14),
#  ('creo', 14),
#  ('mire', 14),
#  ('entera', 14),
#  ('cae', 14),
#  ('lugar', 13),
#  ('voz', 13),
#  ('oscuridad', 13),
#  ('toda', 13),
#  ('boca', 13),
#  ('nadie', 13),
#  ('vas', 13),
#  ('caer', 13),
#  ('azul', 13),
#  ('casa', 13),
#  ('dejo', 13),
#  ('parece', 13),
#  ('madre', 13),
#  ('historia', 13),
#  ('viva', 13),
#  ('sed', 13),
#  ('vamos', 12),
#  ('pista', 12),
#  ('visto', 12),
#  ('saber', 12),
#  ('queda', 12),
#  ('bajo', 12),
#  ('guitarra', 12),
#  ('dónde', 12),
#  ('apenas', 12),
#  ('manera', 12),
#  ('lado', 12),
#  ('manos', 12),
#  ('alrededor', 12),
#  ('luego', 12),
#  ('estrellas', 12),
#  ('you', 12),
#  ('tierra', 12),
#  ('dios', 12),
#  ('momento', 12),
#  ('hablaba', 12),
#  ('veces', 11),
#  ('edad', 11),
#  ('dentro', 11),
#  ('vuela', 11),
#  ('miraba', 11),
#  ('eco', 11),
#  ('años', 11),
#  ('abajo', 11),
#  ('cuatro', 11),
#  ('llena', 11),
#  ('cuero', 11),
#  ('mismo', 11),
#  ('ahora', 11),
#  ('transforma', 11),
#  ('besos', 10),
#  ('sombra', 10),
#  ('caminando', 10),
#  ('sabe', 10),
#  ('mirada', 10),
#  ('miro', 10),
#  ('siento', 10),
#  ('rumbo', 10),
#  ('carbón', 10),
#  ('tambor', 10),
#  ('fuego', 10),
#  ('par', 10),
#  ('quiera', 10),
#  ('vale', 10),
#  ('veo', 10),
#  ('instante', 10),
#  ('quién', 10),
#  ('viene', 9),
#  ('color', 9),
#  ('dejando', 9),
#  ('digo', 9),
#  ('pase', 9),
#  ('pie', 9),
#  ('verso', 9),
#  ('mesa', 9),
#  ('gota', 9),
#  ('puede', 9),
#  ('calor', 9),
#  ('afuera', 9),
#  ('nube', 9),
#  ('entrar', 9),
#  ('tocar', 9),
#  ('mirar', 9),
#  ('supe', 9),
#  ('deja', 9),
#  ('parte', 9),
#  ('decir', 9),
#  ('vienen', 9),
#  ('lágrima', 9),
#  ('pensando', 9),
#  ('mirando', 9),
#  ('suelo', 9),
#  ('guerra', 9),
#  ('bis', 9),
#  ('beso', 9),
#  ('princesa', 9),
#  ('hacer', 9),
#  ('soledad', 9),
#  ('respirar', 8),
#  ('duda', 8),
#  ('playa', 8),
#  ('sonido', 8),
#  ('brillar', 8),
#  ('mira', 8),
#  ('parar', 8),
#  ('ves', 8),
#  ('verde', 8),
#  ('barrio', 8),
#  ('leve', 8),
#  ('tocando', 8),
#  ('canto', 8),
#  ('frío', 8),
#  ('huella', 8),
#  ('tampoco', 8),
#  ('razón', 8),
#  ('gente', 8),
#  ('pone', 8),
#  ('seguir', 8),
#  ('cambia', 8),
#  ('perdido', 8),
#  ('cerrar', 8),
#  ('cosas', 8),
#  ('vacío', 8),
#  ('propia', 8),
#  ('sabes', 8),
#  ('hielo', 8),
#  ('sido', 8),
#  ('aprende', 8),
#  ('pierde', 8),
#  ('oh', 8),
#  ('claro', 8),
#  ('and', 8),
#  ('centro', 8),
#  ('sal', 7),
#  ('vine', 7),
#  ('mareas', 7),
#  ('cambió', 7),
#  ('ropa', 7),
#  ('espejo', 7),
#  ('segundo', 7),
#  ('dolor', 7),
#  ('ventana', 7),
#  ('fuente', 7),
#  ('haciendo', 7),
#  ('hablar', 7),
#  ('cama', 7),
#  ('humo', 7),
#  ('balcón', 7),
#  ('empieza', 7),
#  ('blancas', 7),
#  ('cruz', 7),
#  ('alma', 7),
#  ('mitad', 7),
#  ('padre', 7),
#  ('lengua', 7),
#  ('fin', 7),
#  ('llevo', 7),
#  ('propio', 7),
#  ('dejar', 7),
#  ('mil', 7),
#  ('algún', 7),
#  ('cuenta', 7),
#  ('quisiera', 7),
#  ('cuesta', 7),
#  ('brisa', 7),
#  ('tal', 7),
#  ('importa', 7),
#  ('puerta', 7),
#  ('toque', 7),
#  ('punto', 7),
#  ('santa', 6),
#  ('distancia', 6),
#  ('dicen', 6),
#  ('cambio', 6),
#  ('unas', 6),
#  ('nubes', 6),
#  ('salir', 6),
#  ('ningún', 6),
#  ('gesto', 6),
#  ('dice', 6),
#  ('oro', 6),
#  ('quedó', 6),
#  ('girar', 6),
#  ('días', 6),
#  ('volver', 6),
#  ('tener', 6),
#  ('después', 6),
#  ('barco', 6),
#  ('mueve', 6),
#  ('vapor', 6),
#  ('memoria', 6),
#  ('heridas', 6),
#  ('ven', 6),
#  ('fugaz', 6),
#  ('ninguno', 6),
#  ('peor', 6),
#  ('madrid', 6),
#  ('nueva', 6),
#  ('pasa', 6),
#  ('pies', 6),
#  ('llevan', 6),
#  ('compás', 6),
#  ('contigo', 6),
#  ('eterno', 6),
#  ('quimera', 6),
#  ('breve', 6),
#  ('cantando', 6),
#  ('temprano', 6),
#  ('alegría', 6),
#  ('sueño', 6),
#  ('gracias', 6),
#  ('ciencia', 6),
#  ('hermanos', 6),
#  ('tantos', 6),
#  ('detrás', 6),
#  ('anhelo', 6),
#  ('movimiento', 6),
#  ('recibe', 6),
#  ('todas', 6),
#  ('hermana', 6),
#  ('i', 6),
#  ('pluma', 6),
#  ('cueva', 6),
#  ('nomás', 6),
#  ('bolsillos', 6),
#  ('cuento', 6),
#  ('tras', 5),
#  ('caricia', 5),
#  ('bruma', 5),
#  ('faro', 5),
#  ('detenido', 5),
#  ('primera', 5),
#  ('andar', 5),
#  ('verdad', 5),
#  ('vacía', 5),
#  ('alguna', 5),
#  ('baile', 5),
#  ('espalda', 5),
#  ('espejos', 5),
#  ('nuevo', 5),
#  ('esperar', 5),
#  ('recordar', 5),
#  ('ve', 5),
#  ('vio', 5),
#  ('estela', 5),
#  ('cosa', 5),
#  ('emoción', 5),
#  ('calle', 5),
#  ('crece', 5),
#  ('flota', 5),
#  ('madera', 5),
#  ('tres', 5),
#  ('cuarto', 5),
#  ('dormir', 5),
#  ('fumar', 5),
#  ('buscar', 5),
#  ('cualquiera', 5),
#  ('acerca', 5),
#  ('sonrisa', 5),
#  ('entender', 5),
#  ('acariciar', 5),
#  ('veas', 5),
#  ('pude', 5),
#  ('regresar', 5),
#  ('junto', 5),
#  ('nieve', 5),
#  ('cura', 5),
#  ('peso', 5),
#  ('darte', 5),
#  ('ayer', 5),
#  ('moneda', 5),
#  ('caso', 5),
#  ('fuerza', 5),
#  ('vaya', 5),
#  ('trajo', 5),
#  ('atrás', 5),
#  ('pienses', 5),
#  ('puertas', 5),
#  ('destino', 5),
#  ('enseña', 5),
#  ('tiempos', 5),
#  ('cabe', 5),
#  ('vayas', 5),
#  ('hijo', 5),
#  ('noches', 5),
#  ('oyendo', 5),
#  ('efecto', 5),
#  ('venir', 5),
#  ('haber', 5),
#  ('hecho', 5),
#  ('vaso', 5),
#  ('nombre', 5),
#  ('deseo', 5),
#  ('espacio', 5),
#  ('pronto', 5),
#  ('versos', 5),
#  ('gira', 5),
#  ('encuentro', 5),
#  ('suspiro', 5),
#  ('pulso', 5),
#  ('12', 5),
#  ('segundos', 5),
#  ('mensaje', 5),
#  ('nace', 5),
#  ('siete', 5),
#  ('trama', 5),
#  ('oídos', 5),
#  ('carbonero', 5),
#  ('despedir', 5),
#  ('poderosa', 5),
#  ('polen', 5),
#  ('empeño', 5),
#  ('cabo', 4),
#  ('caminar', 4),
#  ('regazo', 4),
#  ('resplandor', 4),
#  ('canta', 4),
#  ('rumor', 4),
#  ('dunas', 4),
#  ('dejó', 4),
#  ('luces', 4),
#  ('siguió', 4),
#  ('salón', 4),
#  ('mejilla', 4),
#  ('lunar', 4),
#  ('frente', 4),
#  ('sutil', 4),
#  ('cintura', 4),
#  ('fácil', 4),
#  ('premio', 4),
#  ('vaivén', 4),
#  ('cara', 4),
#  ('estira', 4),
#  ('presa', 4),
#  ('carnaval', 4),
#  ('año', 4),
#  ('horizonte', 4),
#  ('sangre', 4),
#  ('verano', 4),
#  ('invierno', 4),
#  ('febrero', 4),
#  ('plata', 4),
#  ('bar', 4),
#  ('clara', 4),
#  ('cruza', 4),
#  ('primavera', 4),
#  ('salgo', 4),
#  ('aguas', 4),
#  ('golpe', 4),
#  ('toca', 4),
#  ('parecen', 4),
#  ('querer', 4),
#  ('aprendí', 4),
#  ('mirándote', 4),
#  ('callado', 4),
#  ('red', 4),
#  ('ana', 4),
#  ('suelto', 4),
#  ('recuerdo', 4),
#  ('final', 4),
#  ('ganas', 4),
#  ('tren', 4),
#  ('simple', 4),
#  ('herida', 4),
#  ('estrella', 4),
#  ('falta', 4),
#  ('toma', 4),
#  ('ira', 4),
#  ('llevando', 4),
#  ('zamba', 4),
#  ('lados', 4),
#  ('vengo', 4),
#  ('buena', 4),
#  ('cantar', 4),
#  ('pasto', 4),
#  ('contento', 4),
#  ('mañana', 4),
#  ('rincones', 4),
#  ('abre', 4),
#  ('brazos', 4),
#  ('murga', 4),
#  ('mejor', 4),
#  ('sigas', 4),
#  ('morir', 4),
#  ('paloma', 4),
#  ('llegó', 4),
#  ('cristal', 4),
#  ('mente', 4),
#  ('sitio', 4),
#  ('prefiero', 4),
#  ('causa', 4),
#  ('flor', 4),
#  ('calma', 4),
#  ('puñado', 4),
#  ('dulce', 4),
#  ('espera', 4),
#  ('miedo', 4),
#  ('abuelo', 4),
#  ('conmigo', 4),
#  ('regreso', 4),
#  ('puesto', 4),
#  ('gravedad', 4),
#  ('duele', 4),
#  ('relojes', 4),
#  ('llegar', 4),
#  ('siguiendo', 4),
#  ('trata', 4),
#  ('dura', 4),
#  ('generaciones', 4),
#  ('mismas', 4),
#  ('queríamos', 4),
#  ('colgados', 4),
#  ('cuánto', 4),
#  ('poesía', 4),
#  ('busca', 4),
#  ('papel', 4),
#  ('corazones', 4),
#  ('varios', 4),
#  ('alguien', 4),
#  ('hoja', 4),
#  ('bella', 4),
#  ('demora', 4),
#  ('hombre', 4),
#  ('polvo', 4),
#  ('vive', 4),
#  ('hizo', 4),
#  ('lejano', 4),
#  ('tanta', 4),
#  ('iba', 4),
#  ('sigue', 4),
#  ('jardinero', 4),
#  ('extraño', 4),
#  ('come', 4),
#  ('go', 4),
#  ('wait', 4),
#  ('noticia', 4),
#  ('entonces', 4),
#  ('pregunto', 4),
#  ('mínimo', 4),
#  ('melancolía', 4),
#  ('duró', 4),
#  ('sino', 4),
#  ('dijo', 4),
#  ('foco', 4),
#  ('codicia', 4),
#  ('bebe', 4),
#  ('llega', 4),
#  ('regalo', 4),
#  ('caerá', 4),
#  ('nota', 4),
#  ('copas', 4),
#  ('quería', 4),
#  ('bienvenida', 3),
#  ('gestos', 3),
#  ('repite', 3),
#  ('2', 3),
#  ('equipaje', 3),
#  ('siglos', 3),
#  ('miran', 3),
#  ('ciudad', 3),
#  ('honda', 3),
#  ('mirador', 3),
#  ('verla', 3),
#  ('espuma', 3),
#  ('mentira', 3),
#  ('orilla', 3),
#  ('bolso', 3),
#  ('amigas', 3),
#  ('salió', 3),
#  ('violetas', 3),
#  ('abrazó', 3),
#  ('giraba', 3),
#  ('conversando', 3),
#  ('club', 3),
#  ('rigor', 3),
#  ('mostrador', 3),
#  ('mesas', 3),
#  ('clase', 3),
#  ('multitud', 3),
#  ('ayudó', 3),
#  ('vió', 3),
#  ('oscurecer', 3),
#  ('dudó', 3),
#  ('besó', 3),
#  ('fingiendo', 3),
#  ('roja', 3),
#  ('mojan', 3),
#  ('mujer', 3),
#  ('iré', 3),
#  ('irá', 3),
#  ('dirás', 3),
#  ('mover', 3),
#  ('controlar', 3),
#  ('porvenir', 3),
#  ('jurando', 3),
#  ('repetir', 3),
#  ('supo', 3),
#  ('doler', 3),
#  ('cuentes', 3),
#  ('revés', 3),
#  ('recobrar', 3),
#  ('vuelto', 3),
#  ('reflejo', 3),
#  ('murmullo', 3),
#  ('salado', 3),
#  ('caía', 3),
#  ('sola', 3),
#  ('pasaron', 3),
#  ('pueden', 3),
#  ('prueba', 3),
#  ('foto', 3),
#  ('tristeza', 3),
#  ('avenida', 3),
#  ('entrando', 3),
#  ('edén', 3),
#  ('pensaba', 3),
#  ('común', 3),
#  ('enero', 3),
#  ('aquél', 3),
#  ('reír', 3),
#  ('secretos', 3),
#  ('pueda', 3),
#  ('rie', 3),
#  ('lala', 3),
#  ('té', 3),
#  ('collar', 3),
#  ('marcha', 3),
#  ('mayor', 3),
#  ('sigo', 3),
#  ('colores', 3),
#  ('costado', 3),
#  ('norte', 3),
#  ('deriva', 3),
#  ('pañuelo', 3),
#  ('escucho', 3),
#  ('conozco', 3),
#  ('entero', 3),
#  ('haga', 3),
#  ('grano', 3),
#  ('cauce', 3),
#  ('timón', 3),
#  ('brillando', 3),
#  ('intención', 3),
#  ('primero', 3),
#  ('piano', 3),
#  ('banderas', 3),
#  ('viejo', 3),
#  ('hará', 3),
#  ('almohada', 3),
#  ('pecho', 3),
#  ('cuna', 3),
#  ('olvido', 3),
#  ('conocer', 3),
#  ('vueltas', 3),
#  ('salto', 3),
#  ('hagas', 3),
#  ('entenderlo', 3),
#  ('quiso', 3),
#  ('borde', 3),
#  ('hijos', 3),
#  ('miedos', 3),
#  ('país', 3),
#  ('milonga', 3),
#  ('prima', 3),
#  ('lejana', 3),
#  ('queriendo', 3),
#  ('buscándote', 3),
#  ('partir', 3),
#  ('reggae', 3),
#  ('estación', 3),
#  ('esperes', 3),
#  ('dedos', 3),
#  ('frase', 3),
#  ('brilla', 3),
#  ('lento', 3),
#  ('pasado', 3),
#  ('carretera', 3),
#  ('existe', 3),
#  ('digas', 3),
#  ('antiguo', 3),
#  ('aún', 3),
#  ('niño', 3),
#  ('golpeando', 3),
#  ('pasan', 3),
#  ('escapando', 3),
#  ('ombligo', 3),
#  ('semana', 3),
#  ('comer', 3),
#  ('termina', 3),
#  ('estaciones', 3),
#  ('abrir', 3),
#  ('cualquier', 3),
#  ('basta', 3),
#  ('escrita', 3),
#  ('palma', 3),
#  ('fechas', 3),
#  ('vivo', 3),
#  ('quizás', 3),
#  ('adentro', 3),
#  ('meta', 3),
#  ('echar', 3),
#  ('contarte', 3),
#  ('sepas', 3),
#  ('lleva', 3),
#  ('crea', 3),
#  ('cierto', 3),
#  ('llevas', 3),
#  ('tragando', 3),
#  ('tantas', 3),
#  ('suerte', 3),
#  ('escuche', 3),
#  ('escuchen', 3),
#  ('triste', 3),
#  ('palabras', 3),
#  ('quedarme', 3),
#  ('latiendo', 3),
#  ('abrazo', 3),
#  ('caminos', 3),
#  ('pueblo', 3),
#  ('medio', 3),
#  ('millones', 3),
#  ('distante', 3),
#  ('respira', 3),
#  ('embargo', 3),
#  ('eternamente', 3),
#  ('vuelo', 3),
#  ('mismos', 3),
#  ('ladrillo', 3),
#  ('prensa', 3),
#  ('aurora', 3),
#  ('preciso', 3),
#  ('espiral', 3),
#  ('piedra', 3),
#  ('profundo', 3),
#  ('cristianos', 3),
#  ('viste', 3),
#  ('galaxia', 3),
#  ('obsesión', 3),
#  ('oigo', 3),
#  ('norma', 3),
#  ('llama', 3),
#  ('haz', 3),
#  ('vea', 3),
#  ('alta', 3),
#  ('buscaba', 3),
#  ('cerrada', 3),
#  ('deje', 3),
#  ('bolivia', 3),
#  ('san', 3),
#  ('niños', 3),
#  ('celos', 3),
#  ('mundos', 3),
#  ('noria', 3),
#  ('evidente', 3),
#  ('palabra', 3),
#  ('ejemplo', 3),
#  ('decía', 3),
#  ('debió', 3),
#  ('fría', 3),
#  ('reposo', 3),
#  ('pienso', 3),
#  ('parezca', 3),
#  ('cicatrices', 3),
#  ('sei', 3),
#  ('vai', 3),
#  ('sera', 3),
#  ('quieres', 3),
#  ('vientos', 3),
#  ('suelta', 3),
#  ('paciencia', 3),
#  ('extraña', 3),
#  ('oscura', 3),
#  ('ritmo', 3),
#  ('asombro', 3),
#  ('mariposa', 3),
#  ('cante', 3),
#  ('sordos', 3),
#  ('dado', 3),
#  ('saberlo', 3),
#  ('decían', 3),
#  ('caliente', 3),
#  ('penúltimo', 3),
#  ('traía', 3),
#  ('pierda', 3),
#  ('detalle', 3),
#  ('amantes', 3),
#  ('hacía', 3),
#  ('planeta', 3),
#  ('sube', 3),
#  ('universos', 3),
#  ('roba', 3),
#  ('nombres', 3),
#  ('bares', 3),
#  ('mandato', 3),
#  ('baño', 3),
#  ('sueños', 3),
#  ('hiciste', 3),
#  ('salvavidas', 3),
#  ('quise', 3),
#  ('simplemente', 3),
#  ('maría', 2),
#  ('dándome', 2),
#  ('saliendo', 2),
#  ('abraza', 2),
#  ('acuerda', 2),
#  ('cosquillas', 2),
#  ('di', 2),
#  ('prudencia', 2),
#  ('niebla', 2),
#  ('catedral', 2),
#  ('forma', 2),
#  ('zanja', 2),
#  ('invoca', 2),
#  ('marzo', 2),
#  ('vieron', 2),
#  ('flotar', 2),
#  ('ocaso', 2),
#  ('tiré', 2),
#  ('crucé', 2),
#  ('farol', 2),
#  ('botella', 2),
#  ('imaginación', 2),
#  ('caña', 2),
#  ('vigilia', 2),
#  ('seguía', 2),
#  ('empezaba', 2),
#  ('amanecer', 2),
#  ('lentas', 2),
#  ('venimos', 2),
#  ('perdidos', 2),
#  ('ríen', 2),
#  ('dibujándose', 2),
#  ('rojo', 2),
#  ('preguntando', 2),
#  ('macarena', 2),
#  ('aprendiendo', 2),
#  ('sueña', 2),
#  ('última', 2),
#  ('mes', 2),
#  ('sirve', 2),
#  ('madrugada', 2),
#  ('marea', 2),
#  ('veras', 2),
#  ('bahía', 2),
#  ('robar', 2),
#  ('afecta', 2),
#  ('tolerar', 2),
#  ('oir', 2),
#  ('bolsa', 2),
#  ('leche', 2),
#  ('cascabel', 2),
#  ('mete', 2),
#  ('venas', 2),
#  ('velo', 2),
#  ('mediodía', 2),
#  ('probar', 2),
#  ('hundiendo', 2),
#  ('raya', 2),
#  ('llevaba', 2),
#  ('temporal', 2),
#  ('esconden', 2),
#  ('cargan', 2),
#  ('pudieron', 2),
#  ('salvar', 2),
#  ('sopor', 2),
#  ('puntas', 2),
#  ('brillo', 2),
#  ('carmesí', 2),
#  ('salvador', 2),
#  ('diez', 2),
#  ('italia', 2),
#  ('bailaba', 2),
#  ('brasil', 2),
#  ('miró', 2),
#  ('contar', 2),
#  ('imaginar', 2),
#  ('escuchar', 2),
#  ('notas', 2),
#  ('amores', 2),
#  ('darme', 2),
#  ('creas', 2),
#  ('rodeos', 2),
#  ('acá', 2),
#  ('radar', 2),
#  ('trapo', 2),
#  ('hombro', 2),
#  ('riéndose', 2),
#  ('tacto', 2),
#  ('tela', 2),
#  ('pasea', 2),
#  ('vicio', 2),
#  ('barato', 2),
#  ('legal', 2),
#  ('gozo', 2),
#  ('respiración', 2),
#  ('diré', 2),
#  ('horarios', 2),
#  ('orden', 2),
#  ('placard', 2),
#  ('toalla', 2),
#  ('sofá', 2),
#  ('trago', 2),
#  ('fumo', 2),
#  ('fruto', 2),
#  ('sabor', 2),
#  ('esperándome', 2),
#  ('fuí', 2),
#  ('quedé', 2),
#  ('reloj', 2),
#  ('daría', 2),
#  ('entro', 2),
#  ('entró', 2),
#  ('quieras', 2),
#  ('banda', 2),
#  ('saben', 2),
#  ('violeta', 2),
#  ('carmín', 2),
#  ('enredadera', 2),
#  ('ten', 2),
#  ('mortal', 2),
#  ('blues', 2),
#  ('negra', 2),
#  ('nombrarte', 2),
#  ('anochecer', 2),
#  ('recordarte', 2),
#  ('marías', 2),
#  ('onda', 2),
#  ('vals', 2),
#  ('esconder', 2),
#  ('culpa', 2),
#  ('bolero', 2),
#  ('miras', 2),
#  ('to', 2),
#  ('pide', 2),
#  ('olvides', 2),
#  ('dure', 2),
#  ('pasándolo', 2),
#  ('mal', 2),
#  ('creer', 2),
#  ('debo', 2),
#  ('mala', 2),
#  ('broma', 2),
#  ('serio', 2),
#  ('hable', 2),
#  ('mezcla', 2),
#  ('abuelos', 2),
#  ('berlín', 2),
#  ('casualidad', 2),
#  ('claridad', 2),
#  ('crecen', 2),
#  ('serpiente', 2),
#  ('pasó', 2),
#  ('ganaba', 2),
#  ('página', 2),
#  ('encontraré', 2),
#  ('copla', 2),
#  ('naufragar', 2),
#  ('sabido', 2),
#  ('elegir', 2),
#  ('puerto', 2),
#  ('volviendo', 2),
#  ('dejes', 2),
#  ('encuentra', 2),
#  ('consejos', 2),
#  ('traigo', 2),
#  ('sombras', 2),
#  ('abren', 2),
#  ('desorden', 2),
#  ('paisaje', 2),
#  ('tibia', 2),
#  ('errado', 2),
#  ('viendo', 2),
#  ('añorar', 2),
#  ('verlo', 2),
#  ('aquellos', 2),
#  ('campo', 2),
#  ('felicidad', 2),
#  ('lastima', 2),
#  ('abrió', 2),
#  ('desatino', 2),
#  ('olvidado', 2),
#  ('ruta', 2),
#  ('fronteras', 2),
#  ('dijeron', 2),
#  ('pocas', 2),
#  ('bang', 2),
#  ('volví', 2),
#  ('vestido', 2),
#  ('candombe', 2),
#  ('prisionero', 2),
#  ('duerme', 2),
#  ('esperando', 2),
#  ('curando', 2),
#  ('hambre', 2),
#  ('bacana', 2),
#  ('corre', 2),
#  ('pensar', 2),
#  ('ley', 2),
#  ('larga', 2),
#  ...]

# %%
def threshold_and_plot_wordcloud_from_list(a_list, a_range):
    
    a_min = a_range[0]
    a_max = a_range[1]
    
    thresholded_intersection = []
    for element in a_list:
        if element[1] >= a_min and element[1] < a_max:
            thresholded_intersection.append(element)

    freqs_by_words = {}
    for a_topic_term in thresholded_intersection:
        an_actual_word = a_topic_term[0]
        freqs_by_words[an_actual_word] = a_topic_term[1]
    # read the mask image
    trump_mask = np.array(Image.open("heart.jpg"))

    wc = WordCloud(background_color="white", max_words=2000, mask=trump_mask, max_font_size=100,)
    # generate word cloud
    wc.generate_from_frequencies(freqs_by_words)

    #show
    plt.figure(figsize=(20,20))
    plt.imshow(wc, cmap=plt.cm.gray, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
threshold_and_plot_wordcloud_from_list(intersection.most_common(), (2,3))

# %%
plot_wordcloud_from_list(counts_drexler.most_common(500))

# %% [markdown]
# http://sentiment.nrc.ca/lexicons-for-research/
#
# http://saifmohammad.com/WebPages/AccessResource.htm
#
# https://github.com/dropofwill/py-lex

# %%
import nltk

# %%
lexicon

# %%
Trailed by the Russia investigation, back-stabbing within his administration, looming midterm elections and Judge Brett Kavanaugh’s troubled nomination, President Trump arrived this week in New York distracted and under siege. At first blush, Mr. Trump’s second appearance at the United Nations General Assembly may have seemed like more self-congratulatory bluster, nationalist isolationism and rote genuflection to the altar of sovereignty — much like last year. But this time, Americans suffered the added humiliation of watching the world burst out laughing at their president, whose false bravado no longer induces shock but invites derision.

Given this drama, it’s easy to mistake Mr. Trump’s visit for a mash-up of meetings and muddled messages. But careful observers should not be diverted from discerning the president’s real purpose at the United Nations, because it is ominous.

On four critical policy fronts, President Trump foreshadowed his intention to ignore our greatest threats and to stoke fresh conflict where it is neither necessary nor wise. More telling than his rabidly ideological speech to the General Assembly was the president’s more substantive remarks before the Security Council on Wednesday. And by now we have ample reason to conclude that Mr. Trump generally means what he says and (eventually) does much of what he threatens.

First, President Trump doubled down on his determination to exonerate Russia and minimize the serious threat that it poses to us and our allies. In a Security Council session devoted to the preventing the proliferation of chemical, biological and nuclear weapons, Mr. Trump ignored Russia’s recent attack with a deadly nerve agent that severely sickened four people in Britain and may have killed one other. He neglected to name Russia as the principal violator of United Nations sanctions on North Korea. And he failed to condemn Russia’s repeated lies to cover for Syria’s use of chemical weapons.

Not once in a visit whose central theme was American sovereignty did Mr. Trump mention Russia’s extraordinary and continuing interference in our democratic process. For reasons we can only hope will soon become clear, President Trump remains determined to coddle our most dangerous adversary, to the increasing detriment of our national security.
""")

# %%
summary = lexicon.summarize_doc(document)

# %%
summary
# Out:
# {'anger': 0.0273972602739726,
#  'anticipation': 0.01643835616438356,
#  'disgust': 0.0136986301369863,
#  'fear': 0.021917808219178082,
#  'joy': 0.005479452054794521,
#  'negative': 0.06027397260273973,
#  'positive': 0.09041095890410959,
#  'sadness': 0.0136986301369863,
#  'surprise': 0.030136986301369864,
#  'trust': 0.06301369863013699}

# %%
summary = lexicon.summarize_annotation(annotation, document)
summary
# Out:
# {'anger': 0.0273972602739726,
#  'anticipation': 0.01643835616438356,
#  'disgust': 0.0136986301369863,
#  'fear': 0.021917808219178082,
#  'joy': 0.005479452054794521,
#  'negative': 0.06027397260273973,
#  'positive': 0.09041095890410959,
#  'sadness': 0.0136986301369863,
#  'surprise': 0.030136986301369864,
#  'trust': 0.06301369863013699}

# %%
len(lexicon)
# Out:
# 10
